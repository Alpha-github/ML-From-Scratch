# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
import sklearn as sk
import random
random.seed(52)

# %%
data, labels = datasets.make_classification(n_samples = 200, n_features=2, n_redundant=0, n_clusters_per_class=1, random_state=20, n_informative=2)

# %%
plt.scatter(data[:,0], data[:,1], c = labels)
